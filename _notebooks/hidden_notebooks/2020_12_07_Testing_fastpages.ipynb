# %% [markdown]
# # "Notebook blog test"
# > "Just a test of fastpages"
#
# - toc: false
# - branch: master
# - badges: true
# - comments: true
# - categories: [fastpages, jupyter, new_tag]
# - image: images/background1.jpg
# - hide: false

# %% [markdown]
# # Let's test!
# Welcome to this exciting blog post where we will test fastpages' functionality.

# %% [markdown]
# ## Coding time

# %%
# This is some code
print("Hello, world.")
# Out:
# Hello, world.

# %%
#hide
# !pip install pandas

# %%
#hide
import pandas as pd

# %%
data = [["Peter", 5], ["Paul", 10], ["Mary", 15]]
df = pd.DataFrame(data, columns=["Name", "Value"])

# %%
df.head()
# Out:
#     Name  Value
# 0  Peter      5
# 1   Paul     10
# 2   Mary     15

# %% [markdown]
# This is some *markdown* to **highlight** the importance of the `code`. Also, we're trying advanced stuff like
#
#
# *   Lists
# *   Lines
#
# ---
# That's about it.
#
# What about images?
#
# ![apple-touch-icon.png](data:image/png;base64,...)

# %% [markdown]
# ## More code

# %%
# Some more code
class TestClass():
  def __init__(self, param=0):
    self.param = param
  def do_something(self):
    print("Something!")

# %%
obj = TestClass()
obj.do_something()
# Out:
# Something!

# %% [markdown]
# ## Thank you for reading
# I hope you enjoyed it. Follow me on [Twitter](https://twitter.com/daflowjoe) 😊
